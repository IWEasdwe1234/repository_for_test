# %% [markdown]
# # T-CR1-CAL01_온도.csv

# %% [markdown]
# ## 1. 기본 정보

# %% [markdown]
# ### `MEAS_DT` (계측시각)
# 약어풀이: <u>**Meas**</u>urement <u>**D**</u>a<u>**t**</u>e\
# 의미: 계측시각 (데이터 계측이 이루어진 날짜 및 시각)
#
# ### `LOT_NO` (로트번호)
# 약어풀이: <u>**Lot**</u> <u>**No**</u>mber\
# 의미: 로트번호 (강종 단위의 통판 묶음을 식별하는 번호)
#
# ### `CLN-IN` (세정조 입측 온도)
# 약어풀이: <u>**Cl**</u>ea<u>**n**</u>ing <u>**In**</u>let\
# 의미: 세정조 입측 온도 (세정 공정 입측 부근의 측정 온도)
#
# ---

# %% [markdown]
# ## 2. 건조존

# %% [markdown]
# ### `TC-Z1` (건조존 1존 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Z**</u>one <u>**1**</u>\
# 의미: 건조존 1존 온도 (건조존 1구간 열전대 측정 온도)
#
# ### `TC-Z2` (건조존 2존 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Z**</u>one <u>**2**</u>\
# 의미: 건조존 2존 온도 (건조존 2구간 열전대 측정 온도)
#
# ### `OP-Z1` (건조존 1존 제어 출력)
# 약어풀이: <u>**O**</u>perating <u>**P**</u>ower - <u>**Z**</u>one <u>**1**</u>\
# 의미: 건조존 1존 제어 출력 (건조존 1구간 히터/버너 출력 비율)
#
# ### `OP-Z2` (건조존 2존 제어 출력)
# 약어풀이: <u>**O**</u>perating <u>**P**</u>ower - <u>**Z**</u>one <u>**2**</u>\
# 의미: 건조존 2존 제어 출력 (건조존 2구간 히터/버너 출력 비율)
#
# ---

# %% [markdown]
# ## 3. 가열·균열존

# %% [markdown]
# ### `TC-Z3` (가열·균열존 1존 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Z**</u>one <u>**3**</u>\
# 의미: 가열·균열존 1존 온도 (가열·균열존 1구간 측정 온도)
#
# ### `TC-Z4` (가열·균열존 2존 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Z**</u>one <u>**4**</u>\
# 의미: 가열·균열존 2존 온도 (가열·균열존 2구간 측정 온도)
#
# ### `TC-Z5` (가열·균열존 3존 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Z**</u>one <u>**5**</u>\
# 의미: 가열·균열존 3존 온도 (가열·균열존 3구간 측정 온도)
#
# ### `TC-Z6` (가열·균열존 4존 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Z**</u>one <u>**6**</u>\
# 의미: 가열·균열존 4존 온도 (가열·균열존 4구간 측정 온도)
#
# ### `OP-Z3` (가열·균열존 1존 제어출력)
# 약어풀이: <u>**O**</u>perating <u>**P**</u>ower - <u>**Z**</u>one <u>**3**</u>\
# 의미: 가열·균열존 1존 제어출력 (가열·균열존 1구간 제어 출력 비율)
#
# ### `OP-Z4` (가열·균열존 2존 제어출력)
# 약어풀이: <u>**O**</u>perating <u>**P**</u>ower - <u>**Z**</u>one <u>**4**</u>\
# 의미: 가열·균열존 2존 제어출력 (가열·균열존 2구간 제어 출력 비율)
#
# ### `OP-Z5` (가열·균열존 3존 제어출력)
# 약어풀이: <u>**O**</u>perating <u>**P**</u>ower - <u>**Z**</u>one <u>**5**</u>\
# 의미: 가열·균열존 3존 제어출력 (가열·균열존 3구간 제어 출력 비율)
#
# ### `OP-Z6` (가열·균열존 4존 제어출력)
# 약어풀이: <u>**O**</u>perating <u>**P**</u>ower - <u>**Z**</u>one <u>**6**</u>\
# 의미: 가열·균열존 4존 제어출력 (가열·균열존 4구간 제어 출력 비율)
#
# ---

# %% [markdown]
# ## 4. 카본 포텐셜

# %% [markdown]
# ### `CP-Z4` (카본포텐셜)
# 약어풀이: <u>**C**</u>arbon <u>**P**</u>otential - <u>**Z**</u>one <u>**4**</u>\
# 의미: 카본포텐셜 (가열·균열존 분위기 가스의 탄소 포텐셜 제어값)
#    - 판 표면의 탈탄(탄소가 빠져나가는 현상)이나 침탄(탄소가 과도하게 들어가는 현상)을 막기 위해 가스 투입량을 조절하는 설정/제어 수치(Process Control Value)입니다.
#
# ### `CP-Z4M` (카본포텐셜 모니터)
# 약어풀이: <u>**C**</u>arbon <u>**P**</u>otential - <u>**Z**</u>one <u>**4**</u> <u>**M**</u>onitor\
# 의미: 카본포텐셜 모니터 (가열·균열존 카본포텐셜의 저스케일 모니터링 값)
# - 매우 작고 세밀한 저스케일 수치로, 분위기 제어 상태가 현장에 제대로 반영되고 있는지 실시간으로 센싱하는 실측 신호(Raw Signal)
#
# ---

# %% [markdown]
# ## 5. 과시효대 존

# %% [markdown]
# ### `TC-Z7` (과시효대 1존 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Z**</u>one <u>**7**</u>\
# 의미: 과시효대 1존 온도 (과시효대 1구간 측정 온도)
#
# ### `TC-Z8` (과시효대 2존 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Z**</u>one <u>**8**</u>\
# 의미: 과시효대 2존 온도 (과시효대 2구간 측정 온도)
#
# ### `TC-Z9` (과시효대 슬러지 제거부 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Z**</u>one <u>**9**</u>\
# 의미: 과시효대 슬러지 제거부 온도 (과시효대 슬러지 제거 영역의 측정 온도)
#
# ### `OP-Z7` (과시효대 1존 제어출력)
# 약어풀이: <u>**O**</u>perating <u>**P**</u>ower - <u>**Z**</u>one <u>**7**</u>\
# 의미: 과시효대 1존 제어출력 (과시효대 1구간 제어 출력 비율)
#
# ### `OP-Z8` (과시효대 2존 제어출력)
# 약어풀이: <u>**O**</u>perating <u>**P**</u>ower - <u>**Z**</u>one <u>**8**</u>\
# 의미: 과시효대 2존 제어출력 (과시효대 2구간 제어 출력 비율)
#
# ---

# %% [markdown]
# ## 6. 냉각대 존

# %% [markdown]
# ### `TC-OUT1` (냉각대 1존 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Out**</u>let <u>**1**</u>\
# 의미: 냉각대 1존 온도 (냉각대 1구간 / 출구 1측 측정 온도)
#
# ### `TC-OUT2` (냉각대 2존 온도)
# 약어풀이: <u>**T**</u>hermo<u>**c**</u>ouple - <u>**Out**</u>let <u>**2**</u>\
# 의미: 냉각대 2존 온도 (냉각대 2구간 / 출구 2측 측정 온도)
#
# ---

# %% [markdown]
# ---
# # G-02_조업이벤트.csv

# %% [markdown]
# ### `EVT_ID` (이벤트 번호)
# 약어풀이: <u>**Ev**</u>en<u>**t**</u> <u>**ID**</u>entifier\
# 의미: 이벤트 번호 (이벤트를 식별하는 고유 ID)
#
# ---

# %% [markdown]
# ### `EVT_DT` (발생 시각)
# 약어풀이: <u>**Ev**</u>en<u>**t**</u> <u>**D**</u>ate <u>**T**</u>ime\
# 의미: 발생 시각 (이벤트가 발생한 일시)
#
# ---

# %% [markdown]
# ### `EVT_TYPE` (이벤트 유형)
# 약어풀이: <u>**Ev**</u>en<u>**t**</u> <u>**Type**</u>\
# 의미: 이벤트 유형 (강종, 원료배합, 조업률 변경)
#
# | 이벤트 유형 | 공장 코드 |
# |---|---|
# | <u>**강종변경**</u> | <u>**`CR1`**</u> |
# | 원료배합변경 | `BF1`, `BF2` |
# | 조업률변경 | `SP1`, `SP2` |
#
# ---

# %% [markdown]
# ### `PLANT_CD` (공장 코드)
# 약어풀이: <u>**Plant**</u> <u>**C**</u>o<u>**d**</u>e\
# 의미: 공장 코드 (이벤트가 발생한 설비/공장 식별 코드)
#
# | 공장 코드 | 약어 풀이 |이벤트 유형 |
# |---|---|---|
# | <u>**`CR1`**</u> | <u>**C**</u>old <u>**R**</u>olling (냉연 공장 / Cold Rolling Mill) | <u>**강종변경**</u> |
# | `BF1`, `BF2` | <u>**B**</u>last <u>**F**</u>urnace (고로 / 용광로) | 원료배합변경 |
# | `SP1`, `SP2` | <u>**S**</u>teelmaking <u>**P**</u>lant (제강 공장) | 조업률변경 |
#
# ---

# %% [markdown]
# ### `BEF_VAL` (변경 전 값), `AFT_VAL` (변경 후 값)
# 약어풀이: <u>**Bef**</u>ore <u>**Val**</u>ue, <u>**Aft**</u>er <u>**Val**</u>ue\
# 의미: 변경 전, 후 값 (상태/설정 변경 전 수치 및 명칭)
#
# | 강종 | 약어 풀이 | 의미 |
# |---|---|---|
# | `SPCC` | <u>**S**</u>teel <u>**P**</u>late <u>**C**</u>old <u>**C**</u>ommercial | 일반용 냉간압연 강판 |
# | `SPCD` | <u>**S**</u>teel <u>**P**</u>late <u>**C**</u>old Deep Drawn | 심가공용 냉간압연 강판 |
# | `SPCE` | <u>**S**</u>teel <u>**P**</u>late <u>**C**</u>old Deep Drawn Extra | 초심가공용 냉간압연 강판 |
# | `SPCEN` | <u>**S**</u>teel <u>**P**</u>late <u>**C**</u>old Deep Drawn Extra Non-aging | 비시효성 초심가공용 냉간압연 강판 |
# | `SGCC` | <u>**S**</u>teel <u>**G**</u>alvanized <u>**C**</u>old <u>**C**</u>ommercial | 일반용 용융아연도금 강판 |
# | `SPHC` | <u>**S**</u>teel <u>**P**</u>late <u>**H**</u>ot <u>**C**</u>ommercial | 일반용 열간압연 강판 |
# | `SPFH590` | <u>**S**</u>teel <u>**P**</u>late <u>**F**</u>orming <u>**H**</u>ot, <u>**590**</u> MPa class | 성형용 열간압연 고장력 강판. 590은 인장강도 약 590 MPa 등급을 뜻함 |
# | `DP590` | <u>**D**</u>ual <u>**P**</u>hase, <u>**590**</u> MPa class | 페라이트와 마르텐사이트의 이중조직을 사용하는 590 MPa급 고장력강 |
#
# ---
